# %% [markdown]
# The data we are exploring is about the high school statistics from different school districts in Baltimore during the years 2009-2013

# %% [markdown]
# First let us load the csv file into our data frame dropoffdf

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#create the dataframe dropoffdf (Education_and_Youth__2010-2013.csv)
dropoffdf=pd.read_csv('Education_and_Youth__2010-2013.csv')

# %%
#check if the dataframe is loaded correctly by checking the first few rows
dropoffdf.head(10)
# Out:
#    index                       Neighborhood  eattend10  eattend11  eattend12  \
# 0      0      Allendale/Irvington/S. Hilton       1118       1037        999
# 1      1    Beechfield/Ten Hills/West Hills        574        647        605
# 2      2                      Belair-Edison       1162       1241       1174
# 3      3  Brooklyn/Curtis Bay/Hawkins Point       1011       1093        997
# 4      4                             Canton         90         76         89
# 5      5                  Cedonia/Frankford       1284       1451       1425
# 6      6                        Cherry Hill        833        818        845
# 7      7          Chinquapin Park/Belvedere        381        391        388
# 8      8                Claremont/Armistead        538        605        575
# 9      9                      Clifton-Berea        879        787        754
#
#    eattend13  mattend10  mattend11  mattend12  mattend13  ...  drop12  drop13  \
# ...

# %%
#Let us get to know our data
dropoffdf.shape
# Out:
# (56, 113)

# %%
dropoffdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Columns: 113 entries, index to sclemp13
# dtypes: int64(22), object(91)
# memory usage: 49.6+ KB

# %%
dropoffdf.describe(include=['int'])
# Out:
#            index     eattend10     eattend11     eattend12     eattend13  \
# count  56.000000     56.000000     56.000000     56.000000     56.000000
# mean   27.500000   1169.107143   1196.125000   1162.607143   1180.500000
# std    16.309506   4308.998579   4447.402969   4315.552082   4348.758598
# min     0.000000     90.000000     76.000000     89.000000     84.000000
# 25%    13.750000    376.250000    351.500000    347.750000    358.750000
# 50%    27.500000    555.500000    593.000000    561.500000    602.500000
# 75%    41.250000    824.000000    794.750000    769.250000    776.250000
# max    55.000000  32735.000000  33791.000000  32791.000000  33054.000000
#
#           mattend10     mattend11     mattend12     mattend13    hsattend10  \
# count     56.000000     56.000000     56.000000     56.000000     56.000000
# mean     670.642857    636.589286    619.250000    624.321429   1023.303571
# std     2472.326019   2369.821188   2298.847025   2300.771658   3774.805777
# ...
